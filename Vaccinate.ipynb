# %%
import math
import numpy as np
from PIL import Image
import pandas as pd
import altair as alt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import datetime as dt

# %%
vaccine_data = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
vaccine_loc = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/locations.csv')

# %%
vaccine_data
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 22759     Zimbabwe      ZWE  2021-05-24            914921.0
# 22760     Zimbabwe      ZWE  2021-05-25            927990.0
# 22761     Zimbabwe      ZWE  2021-05-26            937040.0
# 22762     Zimbabwe      ZWE  2021-05-27            953389.0
# 22763     Zimbabwe      ZWE  2021-05-28            976796.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 22759           633635.0                 281286.0                  3888.0
# 22760           639553.0                 288437.0                 13069.0
# 22761           643531.0                 293509.0                  9050.0
# 22762           648121.0                 305268.0                 16349.0
# 22763           656630.0                 320166.0                 23407.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 22759             14380.0                            6.16
# 22760             13719.0                            6.24
# 22761             13194.0                            6.30
# 22762             12285.0                            6.41
# 22763             12695.0                            6.57
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 22759                           4.26                                 1.89
# 22760                           4.30                                 1.94
# 22761                           4.33                                 1.97
# 22762                           4.36                                 2.05
# 22763                           4.42                                 2.15
#
#        daily_vaccinations_per_million
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 22759                           968.0
# 22760                           923.0
# 22761                           888.0
# 22762                           827.0
# 22763                           854.0
#
# [22764 rows x 12 columns]

# %%
vaccine_loc
# Out:
#               location  iso_code  \
# 0          Afghanistan       AFG
# 1              Albania       ALB
# 2              Algeria       DZA
# 3              Andorra       AND
# 4               Angola       AGO
# ..                 ...       ...
# 208              Wales  OWID_WLS
# 209  Wallis and Futuna       WLF
# 210              Yemen       YEM
# 211             Zambia       ZMB
# 212           Zimbabwe       ZWE
#
#                                               vaccines last_observation_date  \
# 0    Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...            2021-05-26
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...            2021-05-27
# 2                                            Sputnik V            2021-02-19
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech            2021-05-17
# 4                                   Oxford/AstraZeneca            2021-05-26
# ..                                                 ...                   ...
# 208       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech            2021-05-27
# 209                                 Oxford/AstraZeneca            2021-05-25
# 210                                 Oxford/AstraZeneca            2021-05-09
# 211              Oxford/AstraZeneca, Sinopharm/Beijing            2021-05-28
# 212                                  Sinopharm/Beijing            2021-05-28
#
#                           source_name  \
# 0           World Health Organization
# 1                  Ministry of Health
# 2                  Ministry of Health
# 3               Government of Andorra
# 4           World Health Organization
# ..                                ...
# 208  Government of the United Kingdom
# 209        SPC Public Health Division
# 210         World Health Organization
# 211              Government of Zambia
# 212                Ministry of Health
#
#                                         source_website
# 0                             https://covid19.who.int/
# 1    https://shendetesia.gov.al/vaksinimi-anticovid...
# 2    https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 3            https://www.govern.ad/covid19_newsletter/
# 4                             https://covid19.who.int/
# ..                                                 ...
# 208  https://coronavirus.data.gov.uk/details/health...
# 209  https://stats.pacificdata.org/vis?tm=covid&pg=...
# 210                           https://covid19.who.int/
# 211  https://www.facebook.com/mohzambia/posts/19196...
# 212  https://twitter.com/MoHCCZim/status/1398356390...
#
# [213 rows x 6 columns]

# %%
del vaccine_loc['last_observation_date']

# %%
vaccine_loc.shape
# Out:
# (213, 5)

# %%
vaccine_data.shape
# Out:
# (22764, 12)

# %%
df_vaccine = pd.merge(vaccine_data, vaccine_loc, on=["location", "iso_code"])

# %%
df_vaccine.isnull().sum()
# Out:
# location                                   0
# iso_code                                   0
# date                                       0
# total_vaccinations                      8977
# people_vaccinated                       9753
# people_fully_vaccinated                12247
# daily_vaccinations_raw                 10988
# daily_vaccinations                       217
# total_vaccinations_per_hundred          8977
# people_vaccinated_per_hundred           9753
# people_fully_vaccinated_per_hundred    12247
# daily_vaccinations_per_million           217
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df_vaccine.drop(['daily_vaccinations_raw'], axis=1)
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 20917     Zimbabwe      ZWE  2021-05-24            914921.0
# 20918     Zimbabwe      ZWE  2021-05-25            927990.0
# 20919     Zimbabwe      ZWE  2021-05-26            937040.0
# 20920     Zimbabwe      ZWE  2021-05-27            953389.0
# 20921     Zimbabwe      ZWE  2021-05-28            976796.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations  \
# 0                    0.0                      NaN                 NaN
# 1                    NaN                      NaN              1367.0
# 2                    NaN                      NaN              1367.0
# 3                    NaN                      NaN              1367.0
# 4                    NaN                      NaN              1367.0
# ...                  ...                      ...                 ...
# 20917           633635.0                 281286.0             14380.0
# 20918           639553.0                 288437.0             13719.0
# 20919           643531.0                 293509.0             13194.0
# 20920           648121.0                 305268.0             12285.0
# 20921           656630.0                 320166.0             12695.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                0.00                           0.00
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 20917                            6.16                           4.26
# 20918                            6.24                           4.30
# 20919                            6.30                           4.33
# 20920                            6.41                           4.36
# 20921                            6.57                           4.42
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                      NaN                             NaN
# 1                                      NaN                            35.0
# 2                                      NaN                            35.0
# 3                                      NaN                            35.0
# 4                                      NaN                            35.0
# ...                                    ...                             ...
# 20917                                 1.89                           968.0
# 20918                                 1.94                           923.0
# 20919                                 1.97                           888.0
# 20920                                 2.05                           827.0
# 20921                                 2.15                           854.0
#
#                                                 vaccines  \
# 0      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# ...                                                  ...
# 20917                                  Sinopharm/Beijing
# 20918                                  Sinopharm/Beijing
# 20919                                  Sinopharm/Beijing
# 20920                                  Sinopharm/Beijing
# 20921                                  Sinopharm/Beijing
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 20917         Ministry of Health
# 20918         Ministry of Health
# 20919         Ministry of Health
# 20920         Ministry of Health
# 20921         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 20917  https://twitter.com/MoHCCZim/status/1398356390...
# 20918  https://twitter.com/MoHCCZim/status/1398356390...
# 20919  https://twitter.com/MoHCCZim/status/1398356390...
# 20920  https://twitter.com/MoHCCZim/status/1398356390...
# 20921  https://twitter.com/MoHCCZim/status/1398356390...
#
# [20922 rows x 14 columns]

# %%
df_vaccine['date'] = pd.to_datetime(df_vaccine['date'])
df_vaccine = df_vaccine.sort_values('date', ascending=True)

df_vaccine['date'] = df_vaccine['date'].dt.strftime('%Y-%m-%d')

# %%
df_vaccine = df_vaccine.rename(columns={'location': 'country'})

# %%
for iso_code in df_vaccine['iso_code'].unique():
    df_vaccine.loc[df_vaccine['iso_code'] == iso_code, :] = df_vaccine.loc[df_vaccine['iso_code'] == iso_code, :].fillna(method='ffill').fillna(0)

# %%
df_vaccine.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
df_vaccine.to_csv('data/df_vaccine.csv')

# %%
df_daily = pd.read_csv(r'C:\Users\Srijhak\Documents\Covid19-dash\data\worldometer_coronavirus_daily_data.csv')
df_summary = pd.read_csv(r'C:\Users\Srijhak\Documents\Covid19-dash\data\worldometer_coronavirus_summary_data.csv')

# %%
df_daily.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
df_summary.head()
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan      Asia            66275        2812.0            56035
# 1      Albania    Europe           132209        2444.0           128732
# 2      Algeria    Africa           126860        3418.0            88346
# 3      Andorra    Europe            13569         127.0            13234
# 4       Angola    Africa            32441         725.0            26778
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0          7428               1124.0                           1669
# 1          1033                 18.0                          45986
# 2         35096                 18.0                           2847
# 3           208                 12.0                         175367
# 4          4938                 11.0                            961
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                            71.0     446456.0                        11244.0
# 1                           850.0     696434.0                       242239.0
# 2                            77.0     230861.0                         5182.0
# 3                          1641.0     193595.0                      2502036.0
# 4                            21.0     553070.0                        16377.0
#
#    population
# 0    39705801
# 1     2874990
# 2    44554310
# 3       77375
# 4    33770175

# %%
df_daily.shape
# Out:
# (102104, 7)

# %%
df_summary.shape
# Out:
# (220, 12)

# %%
df_summary.isnull().sum()
# Out:
# country                            0
# continent                          0
# total_confirmed                    0
# total_deaths                      14
# total_recovered                    0
# active_cases                       0
# serious_or_critical               71
# total_cases_per_1m_population      0
# total_deaths_per_1m_population    19
# total_tests                       10
# total_tests_per_1m_population     10
# population                         0
# dtype: int64

# %%
df_daily.isnull().sum()
# Out:
# date                           0
# country                        0
# cumulative_total_cases         0
# daily_new_cases             6873
# active_cases                   0
# cumulative_total_deaths     6496
# daily_new_deaths           20278
# dtype: int64

# %% [markdown]
# Merging summary data and vaccine data

# %%
print("Countries in the Vaccination Data not in Summary Data")
print([x for x in df_vaccine['country'].unique() if x not in df_summary['country'].unique()])
# Out:
# Countries in the Vaccination Data not in Summary Data
# ['United States', 'Czechia', 'England', 'Scotland', 'Northern Ireland', 'Wales', 'United Kingdom', 'Turks and Caicos Islands', 'Northern Cyprus', 'Isle of Man', 'Guernsey', 'Falkland Islands', 'Macao', 'Bosnia and Herzegovina', 'Trinidad and Tobago', 'North Macedonia', 'Antigua and Barbuda', 'Saint Kitts and Nevis', 'Hong Kong', "Cote d'Ivoire", 'Vietnam', 'Jersey', 'Sao Tome and Principe', 'Saint Vincent and the Grenadines', 'Cape Verde', 'Wallis and Futuna', 'Kosovo', 'Palestine', 'Eswatini', 'Brunei', 'Turkmenistan', 'Nauru', 'Bonaire Sint Eustatius and Saba', 'Timor', 'Democratic Republic of Congo', 'Tonga', 'Tuvalu', 'Sint Maarten (Dutch part)', 'Guinea-Bissau', 'Pitcairn']

# %%
df_vaccine.country = df_vaccine.country.replace().replace({
    "Antigua and Barbuda": "Antigua And Barbuda",
    "Bosnia and Herzegovina": "Bosnia And Herzegovina",
    "Brunei": "Brunei Darussalam",
    "Cape Verde": "Cabo Verde",
    "Cote d'Ivoire": "Cote D Ivoire",
    "Czechia": "Czech Republic", 
    "Democratic Republic of Congo": "Democratic Republic Of The Congo",
    "Falkland Islands": "Falkland Islands Malvinas",
    "Guinea-Bissau": "Guinea Bissau",
    "Isle of Man": "Isle Of Man",
    "North Macedonia": "Macedonia",
    "Northern Cyprus": "Cyprus",
    "Northern Ireland": "Ireland",
    "Saint Kitts and Nevis": "Saint Kitts And Nevis",
    "Saint Vincent and the Grenadines": "Saint Vincent And The Grenadines",
    "Sao Tome and Principe": "Sao Tome And Principe",
    "Sint Maarten (Dutch part)": "Sint Maarten",
    "Timor": "Timor Leste",
    "Trinidad and Tobago": "Trinidad And Tobago",
    "Turks and Caicos Islands": "Turks And Caicos Islands",
    "United Kingdom": "UK",
    "United States": "USA",
    "Vietnam": "Viet Nam",
    "Wallis and Futuna": "Wallis And Futuna Islands"
})

# %%
df_vaccine = df_vaccine[df_vaccine.country.apply(lambda x: x not in ['Bonaire Sint Eustatius and Saba','England','Eswatini','Guernsey','Hong Kong','Jersey','Kosovo','Macao',
'Nauru','Palestine','Pitcairn','Scotland','Tonga','Turkmenistan','Tuvalu', 'Wales'])]

# %%
print([x for x in df_vaccine['country'].unique() if x not in df_summary['country'].unique()])
# Out:
# []

# %%
df_vaccine.to_csv('data/df_vaccine.csv')

# %%
df_vaccine.head()
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 14233  Norway      NOR  2020-12-02                 1.0                1.0
# 14234  Norway      NOR  2020-12-03                 1.0                1.0
# 14235  Norway      NOR  2020-12-04                 2.0                2.0
# 14236  Norway      NOR  2020-12-05                 2.0                2.0
# 14237  Norway      NOR  2020-12-06                 2.0                2.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 14233                      0.0                     0.0                 0.0
# 14234                      0.0                     0.0                 0.0
# 14235                      0.0                     1.0                 0.0
# 14236                      0.0                     0.0                 0.0
# 14237                      0.0                     0.0                 0.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 14233                             0.0                            0.0
# 14234                             0.0                            0.0
# 14235                             0.0                            0.0
# 14236                             0.0                            0.0
# 14237                             0.0                            0.0
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 14233                                  0.0                             0.0
# 14234                                  0.0                             0.0
# 14235                                  0.0                             0.0
# 14236                                  0.0                             0.0
# 14237                                  0.0                             0.0
#
#                        vaccines                           source_name  \
# 14233  Moderna, Pfizer/BioNTech  Norwegian Institute of Public Health
# 14234  Moderna, Pfizer/BioNTech  Norwegian Institute of Public Health
# 14235  Moderna, Pfizer/BioNTech  Norwegian Institute of Public Health
# 14236  Moderna, Pfizer/BioNTech  Norwegian Institute of Public Health
# 14237  Moderna, Pfizer/BioNTech  Norwegian Institute of Public Health
#
#                                           source_website
# 14233  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 14234  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 14235  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 14236  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 14237  https://www.fhi.no/sv/vaksine/koronavaksinasjo...

# %%
# function to easily agrregate columns
def aggregate(df: pd.Series, agg_col: str) -> pd.DataFrame:
    data = df.groupby(["country"])[agg_col].max()
    data = pd.DataFrame(data)
    return data

# %% [markdown]
# combining the vaccine and summary df

# %%
summary = df_summary.set_index("country")
vaccines = df_vaccine[['country', 'vaccines']].drop_duplicates().set_index('country')
summary = summary.join(vaccines)

# %%
df_vaccine.columns[3:-3]
# Out:
# Index(['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
for cols in df_vaccine.columns[3:-3]:
  summary = summary.join(aggregate(df_vaccine,cols))

# %%
summary.head()
# Out:
#             continent  total_confirmed  total_deaths  total_recovered  \
# country
# Afghanistan      Asia            66275        2812.0            56035
# Albania        Europe           132209        2444.0           128732
# Algeria        Africa           126860        3418.0            88346
# Andorra        Europe            13569         127.0            13234
# Angola         Africa            32441         725.0            26778
#
#              active_cases  serious_or_critical  total_cases_per_1m_population  \
# country
# Afghanistan          7428               1124.0                           1669
# Albania              1033                 18.0                          45986
# Algeria             35096                 18.0                           2847
# Andorra               208                 12.0                         175367
# Angola               4938                 11.0                            961
#
#              total_deaths_per_1m_population  total_tests  \
# country
# Afghanistan                            71.0     446456.0
# Albania                               850.0     696434.0
# Algeria                                77.0     230861.0
# Andorra                              1641.0     193595.0
# Angola                                 21.0     553070.0
#
#              total_tests_per_1m_population  ...  \
# country                                     ...
# Afghanistan                        11244.0  ...
# Albania                           242239.0  ...
# Algeria                             5182.0  ...
# Andorra                          2502036.0  ...
# Angola                             16377.0  ...
#
#                                                       vaccines  \
# country
# Afghanistan  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# Albania      Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# Algeria                                              Sputnik V
# Andorra                    Oxford/AstraZeneca, Pfizer/BioNTech
# Angola                                      Oxford/AstraZeneca
#
#             total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# country
# Afghanistan           590454.0           479372.0                 111082.0
# Albania               759043.0           481788.0                 277255.0
# Algeria                75000.0                0.0                      0.0
# Andorra                32317.0            27613.0                   4704.0
# Angola                859979.0           663049.0                 196930.0
#
#              daily_vaccinations_raw  daily_vaccinations  \
# country
# Afghanistan                     0.0             13921.0
# Albania                     23655.0             17565.0
# Algeria                        30.0              3748.0
# Andorra                      2829.0              1182.0
# Angola                          0.0             22570.0
#
#              total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# country
# Afghanistan                            1.52                           1.23
# Albania                               26.38                          16.74
# Algeria                                0.17                           0.00
# Andorra                               41.83                          35.74
# Angola                                 2.62                           2.02
#
#              people_fully_vaccinated_per_hundred  \
# country
# Afghanistan                                 0.29
# Albania                                     9.63
# Algeria                                     0.00
# Andorra                                     6.09
# Angola                                      0.60
#
#              daily_vaccinations_per_million
# country
# Afghanistan                           358.0
# Albania                              6104.0
# Algeria                                85.0
# Andorra                             15298.0
# Angola                                687.0
#
# [5 rows x 21 columns]

# %%
summary['vaccinated_percent'] = summary.total_vaccinations / summary.population * 100
summary['tested_positive'] = summary.total_confirmed / summary.total_tests * 100

# %%
summary.shape
# Out:
# (222, 23)

# %%
summary.to_csv('data/summary_df.csv')

# %%
df_daily
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 102099  2021-5-19     Zimbabwe                 38612.0             17.0
# 102100  2021-5-20     Zimbabwe                 38635.0             23.0
# 102101  2021-5-21     Zimbabwe                 38664.0             29.0
# 102102  2021-5-22     Zimbabwe                 38679.0             15.0
# 102103  2021-5-23     Zimbabwe                 38682.0              3.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# 0                0.0                      0.0               NaN
# 1                0.0                      0.0               NaN
# 2                0.0                      0.0               NaN
# 3                0.0                      0.0               NaN
# 4                0.0                      0.0               NaN
# ...              ...                      ...               ...
# 102099         613.0                   1583.0               0.0
# 102100         623.0                   1585.0               2.0
# 102101         643.0                   1586.0               1.0
# 102102         648.0                   1586.0               0.0
# 102103         643.0                   1586.0               0.0
#
# [102104 rows x 7 columns]

# %%
df_daily['date'] = pd.to_datetime(df_daily['date'])
df_daily = df_daily.sort_values('date', ascending=True)

df_daily['date'] = df_daily['date'].dt.strftime('%Y-%m-%d')

# %%
# use only common countries and dates 
countries = df_vaccine.dropna(subset=['daily_vaccinations'])['country'].unique()
dates = df_vaccine.dropna(subset=['daily_vaccinations'])['date'].unique()
country_mask = df_daily.country.apply(lambda x: x in countries)
date_mask = df_daily.date.apply(lambda x: x in dates)

# generate the visualization data 
columns_to_sum = ['daily_new_cases', 'cumulative_total_cases', 'cumulative_total_deaths', 'active_cases']
daily_cases = df_daily[country_mask & date_mask].groupby('date')[columns_to_sum].sum()
daily_vaccs = df_vaccine.groupby('date')[[ 'daily_vaccinations']].sum()

# make it a dataframe for convenience  
data = pd.DataFrame(daily_cases).join(pd.DataFrame(daily_vaccs))

# bring back the vaccine data we prepared in the previous section 
cumulative_vaccines = pd.DataFrame(df_vaccine.groupby('date')['total_vaccinations'].sum())
data = data.join(cumulative_vaccines).reset_index()

# %%
data.head()
# Out:
#          date  daily_new_cases  cumulative_total_cases  \
# 0  2020-12-02         643702.0              65475274.0
# 1  2020-12-03         689318.0              66164592.0
# 2  2020-12-04         691047.0              66855639.0
# 3  2020-12-05         643747.0              67499386.0
# 4  2020-12-06         551980.0              68051366.0
#
#    cumulative_total_deaths  active_cases  daily_vaccinations  \
# 0                1514215.0    13840161.0                 0.0
# 1                1526969.0    13962280.0                 0.0
# 2                1539275.0    14099032.0                 0.0
# 3                1549824.0    14165027.0                 0.0
# 4                1557926.0    14263405.0                 0.0
#
#    total_vaccinations
# 0                 1.0
# 1                 1.0
# 2                 2.0
# 3                 2.0
# 4                 2.0

# %%
data.to_csv('data/df_daily.csv')
