# %%
import math
import numpy as np
from PIL import Image
import pandas as pd
import altair as alt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import datetime

# %%
vaccine_data = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv')
vaccine_loc = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/locations.csv')

# %%
vaccine_data
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 22537     Zimbabwe      ZWE  2021-05-21            887928.0
# 22538     Zimbabwe      ZWE  2021-05-22            904073.0
# 22539     Zimbabwe      ZWE  2021-05-23            911033.0
# 22540     Zimbabwe      ZWE  2021-05-24            914921.0
# 22541     Zimbabwe      ZWE  2021-05-25            927990.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 22537           624665.0                 263263.0                 20532.0
# 22538           630348.0                 273725.0                 16145.0
# 22539           632496.0                 278537.0                  6960.0
# 22540           633635.0                 281286.0                  3888.0
# 22541           639553.0                 288437.0                 13069.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 22537             16098.0                            5.97
# 22538             15823.0                            6.08
# 22539             16298.0                            6.13
# 22540             14380.0                            6.16
# 22541             13719.0                            6.24
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 22537                           4.20                                 1.77
# 22538                           4.24                                 1.84
# 22539                           4.26                                 1.87
# 22540                           4.26                                 1.89
# 22541                           4.30                                 1.94
#
#        daily_vaccinations_per_million
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 22537                          1083.0
# 22538                          1065.0
# 22539                          1097.0
# 22540                           968.0
# 22541                           923.0
#
# [22542 rows x 12 columns]

# %%
vaccine_loc
# Out:
#               location  iso_code  \
# 0          Afghanistan       AFG
# 1              Albania       ALB
# 2              Algeria       DZA
# 3              Andorra       AND
# 4               Angola       AGO
# ..                 ...       ...
# 208              Wales  OWID_WLS
# 209  Wallis and Futuna       WLF
# 210              Yemen       YEM
# 211             Zambia       ZMB
# 212           Zimbabwe       ZWE
#
#                                               vaccines last_observation_date  \
# 0    Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...            2021-05-26
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...            2021-05-27
# 2                                            Sputnik V            2021-02-19
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech            2021-05-17
# 4                                   Oxford/AstraZeneca            2021-05-26
# ..                                                 ...                   ...
# 208       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech            2021-05-26
# 209                                 Oxford/AstraZeneca            2021-05-25
# 210                                 Oxford/AstraZeneca            2021-05-09
# 211              Oxford/AstraZeneca, Sinopharm/Beijing            2021-05-27
# 212                                  Sinopharm/Beijing            2021-05-25
#
#                           source_name  \
# 0           World Health Organization
# 1                  Ministry of Health
# 2                  Ministry of Health
# 3               Government of Andorra
# 4           World Health Organization
# ..                                ...
# 208  Government of the United Kingdom
# 209        SPC Public Health Division
# 210         World Health Organization
# 211              Government of Zambia
# 212                Ministry of Health
#
#                                         source_website
# 0                             https://covid19.who.int/
# 1    https://shendetesia.gov.al/vaksinimi-anticovid...
# 2    https://www.echoroukonline.com/%d9%84%d9%82%d8...
# 3            https://www.govern.ad/covid19_newsletter/
# 4                             https://covid19.who.int/
# ..                                                 ...
# 208  https://coronavirus.data.gov.uk/details/health...
# 209  https://stats.pacificdata.org/vis?tm=covid&pg=...
# 210                           https://covid19.who.int/
# 211  https://www.facebook.com/mohzambia/posts/19188...
# 212  https://twitter.com/MoHCCZim/status/1397272359...
#
# [213 rows x 6 columns]

# %%
del vaccine_loc['last_observation_date']

# %%
vaccine_loc.shape
# Out:
# (213, 5)

# %%
vaccine_data.shape
# Out:
# (22542, 12)

# %%
df_vaccine = pd.merge(vaccine_data, vaccine_loc, on=["location", "iso_code"])

# %%
df_vaccine.isnull().sum()
# Out:
# location                                   0
# iso_code                                   0
# date                                       0
# total_vaccinations                      8902
# people_vaccinated                       9673
# people_fully_vaccinated                12153
# daily_vaccinations_raw                 10889
# daily_vaccinations                       216
# total_vaccinations_per_hundred          8902
# people_vaccinated_per_hundred           9673
# people_fully_vaccinated_per_hundred    12153
# daily_vaccinations_per_million           216
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df_vaccine.drop(['daily_vaccinations_raw'], axis=1)
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 20708     Zimbabwe      ZWE  2021-05-21            887928.0
# 20709     Zimbabwe      ZWE  2021-05-22            904073.0
# 20710     Zimbabwe      ZWE  2021-05-23            911033.0
# 20711     Zimbabwe      ZWE  2021-05-24            914921.0
# 20712     Zimbabwe      ZWE  2021-05-25            927990.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations  \
# 0                    0.0                      NaN                 NaN
# 1                    NaN                      NaN              1367.0
# 2                    NaN                      NaN              1367.0
# 3                    NaN                      NaN              1367.0
# 4                    NaN                      NaN              1367.0
# ...                  ...                      ...                 ...
# 20708           624665.0                 263263.0             16098.0
# 20709           630348.0                 273725.0             15823.0
# 20710           632496.0                 278537.0             16298.0
# 20711           633635.0                 281286.0             14380.0
# 20712           639553.0                 288437.0             13719.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                0.00                           0.00
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 20708                            5.97                           4.20
# 20709                            6.08                           4.24
# 20710                            6.13                           4.26
# 20711                            6.16                           4.26
# 20712                            6.24                           4.30
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                      NaN                             NaN
# 1                                      NaN                            35.0
# 2                                      NaN                            35.0
# 3                                      NaN                            35.0
# 4                                      NaN                            35.0
# ...                                    ...                             ...
# 20708                                 1.77                          1083.0
# 20709                                 1.84                          1065.0
# 20710                                 1.87                          1097.0
# 20711                                 1.89                           968.0
# 20712                                 1.94                           923.0
#
#                                                 vaccines  \
# 0      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# ...                                                  ...
# 20708                                  Sinopharm/Beijing
# 20709                                  Sinopharm/Beijing
# 20710                                  Sinopharm/Beijing
# 20711                                  Sinopharm/Beijing
# 20712                                  Sinopharm/Beijing
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 20708         Ministry of Health
# 20709         Ministry of Health
# 20710         Ministry of Health
# 20711         Ministry of Health
# 20712         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 20708  https://twitter.com/MoHCCZim/status/1397272359...
# 20709  https://twitter.com/MoHCCZim/status/1397272359...
# 20710  https://twitter.com/MoHCCZim/status/1397272359...
# 20711  https://twitter.com/MoHCCZim/status/1397272359...
# 20712  https://twitter.com/MoHCCZim/status/1397272359...
#
# [20713 rows x 14 columns]

# %%
df_vaccine['date'] = pd.to_datetime(df_vaccine['date'])
df_vaccine = df_vaccine.sort_values('date', ascending=True)

df_vaccine['date'] = df_vaccine['date'].dt.strftime('%Y-%m-%d')

# %%
df_vaccine = df_vaccine.rename(columns={'location': 'country'})

# %%
for iso_code in df_vaccine['iso_code'].unique():
    df_vaccine.loc[df_vaccine['iso_code'] == iso_code, :] = df_vaccine.loc[df_vaccine['iso_code'] == iso_code, :].fillna(method='ffill').fillna(0)

# %%
df_vaccine.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
df_vaccine[df_vaccine['country']=='Australia']
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 909   Australia      AUS  2021-02-15                 0.0                0.0
# 910   Australia      AUS  2021-02-16                 0.0                0.0
# 911   Australia      AUS  2021-02-17                 0.0                0.0
# 912   Australia      AUS  2021-02-18                 0.0                0.0
# 913   Australia      AUS  2021-02-19                 0.0                0.0
# ...         ...      ...         ...                 ...                ...
# 1006  Australia      AUS  2021-05-23           3599964.0           162551.0
# 1007  Australia      AUS  2021-05-24           3613053.0          3196760.0
# 1008  Australia      AUS  2021-05-25           3690622.0          3271385.0
# 1009  Australia      AUS  2021-05-26           3795280.0          3322398.0
# 1010  Australia      AUS  2021-05-27           3906668.0          3426457.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 909                       0.0                     0.0                 0.0
# 910                       0.0                     0.0                 0.0
# 911                       0.0                     0.0                 0.0
# 912                       0.0                     0.0                 0.0
# 913                       0.0                     0.0                 0.0
# ...                       ...                     ...                 ...
# 1006                      0.0                 37469.0             72969.0
# 1007                 416293.0                 13089.0             73274.0
# 1008                 419237.0                 77569.0             72471.0
# 1009                 472882.0                104658.0             73775.0
# 1010                 480211.0                111388.0             76420.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 909                             0.00                           0.00
# 910                             0.00                           0.00
# 911                             0.00                           0.00
# 912                             0.00                           0.00
# 913                             0.00                           0.00
# ...                              ...                            ...
# 1006                           14.12                           0.64
# 1007                           14.17                          12.54
# 1008                           14.47                          12.83
# 1009                           14.88                          13.03
# 1010                           15.32                          13.44
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 909                                  0.00                             0.0
# 910                                  0.00                             0.0
# 911                                  0.00                             0.0
# 912                                  0.00                             0.0
# 913                                  0.00                             0.0
# ...                                   ...                             ...
# 1006                                 0.00                          2862.0
# 1007                                 1.63                          2874.0
# 1008                                 1.64                          2842.0
# 1009                                 1.85                          2893.0
# 1010                                 1.88                          2997.0
#
#                                  vaccines  \
# 909   Oxford/AstraZeneca, Pfizer/BioNTech
# 910   Oxford/AstraZeneca, Pfizer/BioNTech
# 911   Oxford/AstraZeneca, Pfizer/BioNTech
# 912   Oxford/AstraZeneca, Pfizer/BioNTech
# 913   Oxford/AstraZeneca, Pfizer/BioNTech
# ...                                   ...
# 1006  Oxford/AstraZeneca, Pfizer/BioNTech
# 1007  Oxford/AstraZeneca, Pfizer/BioNTech
# 1008  Oxford/AstraZeneca, Pfizer/BioNTech
# 1009  Oxford/AstraZeneca, Pfizer/BioNTech
# 1010  Oxford/AstraZeneca, Pfizer/BioNTech
#
#                                        source_name  \
# 909   Government of Australia via covidlive.com.au
# 910   Government of Australia via covidlive.com.au
# 911   Government of Australia via covidlive.com.au
# 912   Government of Australia via covidlive.com.au
# 913   Government of Australia via covidlive.com.au
# ...                                            ...
# 1006  Government of Australia via covidlive.com.au
# 1007  Government of Australia via covidlive.com.au
# 1008  Government of Australia via covidlive.com.au
# 1009  Government of Australia via covidlive.com.au
# 1010  Government of Australia via covidlive.com.au
#
#                              source_website
# 909   https://covidlive.com.au/vaccinations
# 910   https://covidlive.com.au/vaccinations
# 911   https://covidlive.com.au/vaccinations
# 912   https://covidlive.com.au/vaccinations
# 913   https://covidlive.com.au/vaccinations
# ...                                     ...
# 1006  https://covidlive.com.au/vaccinations
# 1007  https://covidlive.com.au/vaccinations
# 1008  https://covidlive.com.au/vaccinations
# 1009  https://covidlive.com.au/vaccinations
# 1010  https://covidlive.com.au/vaccinations
#
# [102 rows x 15 columns]

# %%
df_vaccine.to_csv('data/df_vaccine.csv')

# %%
df_daily = pd.read_csv(r'C:\Users\Srijhak\Documents\Covid19-dash\data\worldometer_coronavirus_daily_data.csv')
df_summary = pd.read_csv(r'C:\Users\Srijhak\Documents\Covid19-dash\data\worldometer_coronavirus_summary_data.csv')

# %%
df_daily.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
df_summary.head()
# Out:
#        country continent  total_confirmed  total_deaths  total_recovered  \
# 0  Afghanistan      Asia            66275        2812.0            56035
# 1      Albania    Europe           132209        2444.0           128732
# 2      Algeria    Africa           126860        3418.0            88346
# 3      Andorra    Europe            13569         127.0            13234
# 4       Angola    Africa            32441         725.0            26778
#
#    active_cases  serious_or_critical  total_cases_per_1m_population  \
# 0          7428               1124.0                           1669
# 1          1033                 18.0                          45986
# 2         35096                 18.0                           2847
# 3           208                 12.0                         175367
# 4          4938                 11.0                            961
#
#    total_deaths_per_1m_population  total_tests  total_tests_per_1m_population  \
# 0                            71.0     446456.0                        11244.0
# 1                           850.0     696434.0                       242239.0
# 2                            77.0     230861.0                         5182.0
# 3                          1641.0     193595.0                      2502036.0
# 4                            21.0     553070.0                        16377.0
#
#    population
# 0    39705801
# 1     2874990
# 2    44554310
# 3       77375
# 4    33770175

# %%
df_daily.shape
# Out:
# (102104, 7)

# %%
df_summary.shape
# Out:
# (220, 12)

# %%
df_summary.isnull().sum()
# Out:
# country                            0
# continent                          0
# total_confirmed                    0
# total_deaths                      14
# total_recovered                    0
# active_cases                       0
# serious_or_critical               71
# total_cases_per_1m_population      0
# total_deaths_per_1m_population    19
# total_tests                       10
# total_tests_per_1m_population     10
# population                         0
# dtype: int64

# %%
df_daily.isnull().sum()
# Out:
# date                           0
# country                        0
# cumulative_total_cases         0
# daily_new_cases             6873
# active_cases                   0
# cumulative_total_deaths     6496
# daily_new_deaths           20278
# dtype: int64

# %% [markdown]
# Merging summary data and vaccine data

# %%
print("Countries in the Vaccination Data not in Summary Data")
print([x for x in df_vaccine['location'].unique() if x not in df_summary['country'].unique()])
# Out:
# Countries in the Vaccination Data not in Summary Data
# ['Antigua and Barbuda', 'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Brunei', 'Cape Verde', "Cote d'Ivoire", 'Czechia', 'Democratic Republic of Congo', 'England', 'Eswatini', 'Falkland Islands', 'Guernsey', 'Guinea-Bissau', 'Hong Kong', 'Isle of Man', 'Jersey', 'Kosovo', 'Macao', 'Nauru', 'North Macedonia', 'Northern Cyprus', 'Northern Ireland', 'Palestine', 'Pitcairn', 'Saint Kitts and Nevis', 'Saint Vincent and the Grenadines', 'Sao Tome and Principe', 'Scotland', 'Sint Maarten (Dutch part)', 'Timor', 'Tonga', 'Trinidad and Tobago', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'United Kingdom', 'United States', 'Vietnam', 'Wales', 'Wallis and Futuna']

# %%
df_vaccine.location = df_vaccine.location.replace().replace({
    "Antigua and Barbuda": "Antigua And Barbuda",
    "Bosnia and Herzegovina": "Bosnia And Herzegovina",
    "Brunei": "Brunei Darussalam",
    "Cape Verde": "Cabo Verde",
    "Cote d'Ivoire": "Cote D Ivoire",
    "Czechia": "Czech Republic", 
    "Democratic Republic of Congo": "Democratic Republic Of The Congo",
    "Falkland Islands": "Falkland Islands Malvinas",
    "Guinea-Bissau": "Guinea Bissau",
    "Isle of Man": "Isle Of Man",
    "North Macedonia": "Macedonia",
    "Northern Cyprus": "Cyprus",
    "Northern Ireland": "Ireland",
    "Saint Kitts and Nevis": "Saint Kitts And Nevis",
    "Saint Vincent and the Grenadines": "Saint Vincent And The Grenadines",
    "Sao Tome and Principe": "Sao Tome And Principe",
    "Sint Maarten (Dutch part)": "Sint Maarten",
    "Timor": "Timor Leste",
    "Trinidad and Tobago": "Trinidad And Tobago",
    "Turks and Caicos Islands": "Turks And Caicos Islands",
    "United Kingdom": "UK",
    "United States": "USA",
    "Vietnam": "Viet Nam",
    "Wallis and Futuna": "Wallis And Futuna Islands"
})

# %%
df_vaccine = df_vaccine[df_vaccine.location.apply(lambda x: x not in ['Bonaire Sint Eustatius and Saba','England','Eswatini','Guernsey','Hong Kong','Jersey','Kosovo','Macao',
'Nauru','Palestine','Pitcairn','Scotland','Tonga','Turkmenistan','Tuvalu', 'Wales'])]

# %%
print([x for x in df_vaccine['location'].unique() if x not in df_summary['country'].unique()])
# Out:
# []

# %%
df_vaccine.to_csv('data/df_vaccine.csv')

# %%
df_vaccine.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#                                             vaccines  \
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
# function to easily agrregate columns
def aggregate(df: pd.Series, agg_col: str) -> pd.DataFrame:
    data = df.groupby(["country"])[agg_col].max()
    data = pd.DataFrame(data)
    return data

# %% [markdown]
# combining the vaccine and summary df

# %%
summary = df_summary.set_index("country")
vaccines = df_vaccine[['country', 'vaccines']].drop_duplicates().set_index('country')
summary = summary.join(vaccines)

# %%
df_vaccine.columns[3:-3]
# Out:
# Index(['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %%
for cols in df_vaccine.columns[3:-3]:
  summary = summary.join(aggregate(df_vaccine,cols))

# %%
summary.head()
# Out:
#             continent  total_confirmed  total_deaths  total_recovered  \
# country
# Afghanistan      Asia            66275        2812.0            56035
# Albania        Europe           132209        2444.0           128732
# Algeria        Africa           126860        3418.0            88346
# Andorra        Europe            13569         127.0            13234
# Angola         Africa            32441         725.0            26778
#
#              active_cases  serious_or_critical  total_cases_per_1m_population  \
# country
# Afghanistan          7428               1124.0                           1669
# Albania              1033                 18.0                          45986
# Algeria             35096                 18.0                           2847
# Andorra               208                 12.0                         175367
# Angola               4938                 11.0                            961
#
#              total_deaths_per_1m_population  total_tests  \
# country
# Afghanistan                            71.0     446456.0
# Albania                               850.0     696434.0
# Algeria                                77.0     230861.0
# Andorra                              1641.0     193595.0
# Angola                                 21.0     553070.0
#
#              total_tests_per_1m_population  ...  \
# country                                     ...
# Afghanistan                        11244.0  ...
# Albania                           242239.0  ...
# Algeria                             5182.0  ...
# Andorra                          2502036.0  ...
# Angola                             16377.0  ...
#
#                                                       vaccines  \
# country
# Afghanistan  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# Albania      Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# Algeria                                              Sputnik V
# Andorra                    Oxford/AstraZeneca, Pfizer/BioNTech
# Angola                                      Oxford/AstraZeneca
#
#             total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# country
# Afghanistan           590454.0           479372.0                 111082.0
# Albania               759043.0           481788.0                 277255.0
# Algeria                75000.0                NaN                      NaN
# Andorra                32317.0            27613.0                   4704.0
# Angola                859979.0           663049.0                 196930.0
#
#              daily_vaccinations_raw  daily_vaccinations  \
# country
# Afghanistan                     NaN             13921.0
# Albania                     23655.0             17565.0
# Algeria                        30.0              3748.0
# Andorra                      2829.0              1182.0
# Angola                          NaN             22570.0
#
#              total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# country
# Afghanistan                            1.52                           1.23
# Albania                               26.38                          16.74
# Algeria                                0.17                            NaN
# Andorra                               41.83                          35.74
# Angola                                 2.62                           2.02
#
#              people_fully_vaccinated_per_hundred  \
# country
# Afghanistan                                 0.29
# Albania                                     9.63
# Algeria                                      NaN
# Andorra                                     6.09
# Angola                                      0.60
#
#              daily_vaccinations_per_million
# country
# Afghanistan                           358.0
# Albania                              6104.0
# Algeria                                85.0
# Andorra                             15298.0
# Angola                                687.0
#
# [5 rows x 21 columns]

# %%
summary['vaccinated_percent'] = summary.total_vaccinations / summary.population * 100
summary['tested_positive'] = summary.total_confirmed / summary.total_tests * 100

# %%
summary.shape
# Out:
# (222, 23)

# %%
summary.to_csv('data/summary_df.csv')
